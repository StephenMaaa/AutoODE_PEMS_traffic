# %%
import gzip
import shutil

# %%
import os

count = 0
for filename in os.listdir("caltrans/station_5min/2021/d11/"): 
    plaintxt, file_type = filename.split(".gz")
    print(plaintxt)
    with gzip.open("caltrans/station_5min/2021/d11/" + filename, 'rb') as f_in:
        with open("caltrans/station_5min/2021/d11_plaintxt/" + plaintxt, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
            count += 1
# Out:
# d11_text_station_5min_2021_01_01.txt
# d11_text_station_5min_2021_01_02.txt
# d11_text_station_5min_2021_01_03.txt
# d11_text_station_5min_2021_01_04.txt
# d11_text_station_5min_2021_01_05.txt
# d11_text_station_5min_2021_01_06.txt
# d11_text_station_5min_2021_01_07.txt
# d11_text_station_5min_2021_01_08.txt
# d11_text_station_5min_2021_01_09.txt
# d11_text_station_5min_2021_01_10.txt
# d11_text_station_5min_2021_01_11.txt
# d11_text_station_5min_2021_01_12.txt
# d11_text_station_5min_2021_01_13.txt
# d11_text_station_5min_2021_01_14.txt
# d11_text_station_5min_2021_01_15.txt
# d11_text_station_5min_2021_01_16.txt
# d11_text_station_5min_2021_01_17.txt
# d11_text_station_5min_2021_01_18.txt
# d11_text_station_5min_2021_01_19.txt
# d11_text_station_5min_2021_01_20.txt
# d11_text_station_5min_2021_01_21.txt
# d11_text_station_5min_2021_01_22.txt
# d11_text_station_5min_2021_01_23.txt
# d11_text_station_5min_2021_01_24.txt
# d11_text_station_5min_2021_01_25.txt
# ...

# %%
print(count)
# Out:
# 271

# %%
import gzip
import shutil
with gzip.open('caltrans/station_5min/2017/d11/d11_text_station_5min_2017_01_01.txt.gz', 'rb') as f_in:
    with open('caltrans/station_5min/2017/d11_plaintxt/file1.txt', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
